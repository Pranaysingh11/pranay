# %%
with open('assignment1.json') as json_file:
    data = json.load(json_file)
data
# Out:
# {'session_name': 'test',
#  'session_description': 'test',
#  'design_state_data': {'session_info': {'project_id': '1',
#    'experiment_id': 'kkkk-11',
#    'dataset': 'iris_modified.csv',
#    'session_name': 'test',
#    'session_description': 'test'},
#   'target': {'prediction_type': 'Regression',
#    'target': 'petal_width',
#    'type': 'regression',
#    'partitioning': True},
#   'train': {'policy': 'Split the dataset',
#    'time_variable': 'sepal_length',
#    'sampling_method': 'No sampling(whole data)',
#    'split': 'Randomly',
#    'k_fold': False,
#    'train_ratio': 0,
#    'random_seed': 0},
#   'metrics': {'optomize_model_hyperparameters_for': 'AUC',
#    'optimize_threshold_for': 'F1 Score',
#    'compute_lift_at': 0,
#    'cost_matrix_gain_for_true_prediction_true_result': 1,
#    'cost_matrix_gain_for_true_prediction_false_result': 0,
#    'cost_matrix_gain_for_false_prediction_true_result': 0,
#    'cost_matrix_gain_for_false_prediction_false_result': 0},
# ...

# %%
pip install pyth
# Out:
# ...
#   Created wheel for pyth: filename=pyth-0.6.0-py3-none-any.whl size=27087 sha256=d6d202d7930d31798aca4b61f9d19d5c14ede94d1109fcac4f1324ebbda1dddb
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\68\92\95\0863aaa4b1a4b5d03a0eb3ac4fe6c4d604b50cb5d7ca1389eb
# Successfully built pyth
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
    for model_config in models_config:
    model_model_name = model_config['model_name']
    model_is_selected = model_config['is_selected']
    model_min_trees = model_config['min_trees']
    model_max_trees = model_config['max_trees']
    model_feature_sampling_statergy = model_config['feature_sampling_statergy']
    model_min_depth = model_config['min_depth']
    model_max_depth = model_config['max_depth']
    model_min_samples_per_leaf_min_value = model_config['min_samples_per_leaf_min_value']
    model_min_samples_per_leaf_max_value = model_config['min_samples_per_leaf_max_value']
    model_parallelism= model_config['parallelism']
    
    
    
    
    if model_type == 'Random Forest Classifier':
        clf = Random Forest Classifier(**model_params)
    elif model_type == 'KNeighborsClassifier':
        clf = KNeighborsClassifier(**model_params)
    elif model_type == 'DecisionTreeClassifier':
        clf = DecisionTreeClassifier(**model_params)
    elif model_type == 'SVC':
        clf = SVC(**model_params)
    else:
        raise ValueError(f"Invalid model type: {model_type}")
# Out:
#   Input In [23]
#     model_model_name = model_config['model_name']
#     ^
# IndentationError: expected an indented block
